# %%
# !pip install -q -r ../requirements.txt

# %%
import osmnx as ox
import matplotlib.pyplot as plt

# %% [markdown]
# # **São Paulo**

# %%
cidade_nome_sp = "sp"
cidade_grafo_sp = "Sao Paulo, SP, Brazil"

data_sp = "27_06_2022"

# %%
G_sp = ox.io.load_graphml(filepath=f"../data/{cidade_nome_sp}_{data_sp}.graphml")

# %% [markdown]
# ### Plot normal

# %%
fig, ax = ox.plot_graph(G_sp)

# %% [markdown]
# ### Plot interativo

# %%
# %matplotlib tk

fig, ax = ox.plot_graph(G_sp)
plt.show()

# %%
for node in G_sp.nodes(data=True):
    print(node)
    break
# Out:
# (573641, {'y': -23.5629908, 'x': -46.7039651, 'street_count': 3, 'altitude_latlong_mais_proxima': '(-23.5633, -46.7042)', 'altitude_distancia_mais_proxima': '41.8067', 'altitude_metros_mais_proxima': '727.0', 'dentro_poligonos': '[]', 'pontos_candidatos': '[]', 'dicionario_poligonos_mais_proximos': "{'raio_85_vizinhos_14': [{'id_poligono': 972, 'distancia_m': 608.34, 'dentro_poligono': False, 'poligono': 'POLYGON ((-46.6991197314000033 -23.5612398729998986, -46.6991733145713965 -23.5598921287141998, -46.6984343000000024 -23.5597874999999988, -46.6979561034141994 -23.5604592934428005, -46.6989659999999986 -23.5612266999999989, -46.6991197314000033 -23.5612398729998986))', 'cod_setor_GeoCenso_2010': 355030862000075, 'classe_social': '4 - Classe Alta'}, {'id_poligono': 1602, 'distancia_m': 729.46, 'dentro_poligono': False, 'poligono': 'POLYGON ((-46.7039112000000003 -23.5698414999999990, -46.7046844324236972 -23.5696988057288017, -46.7038521449999990 -23.5692167129999000, -46.7037870950
# ...

# %% [markdown]
# # **Curitiba**

# %%
cidade_nome_curitiba = "curitiba"
cidade_grafo_curitiba = "Curitiba, PR, Brazil"

data_curitiba = "07_10_2022"

# %%
G_curitiba = ox.io.load_graphml(filepath=f"../data/{cidade_nome_curitiba}_{data_curitiba}.graphml")

# %% [markdown]
# ## Plot normal

# %%
fig, ax = ox.plot_graph(G_curitiba)

# %% [markdown]
# ## Plot interativo

# %%
# %matplotlib tk

fig, ax = ox.plot_graph(G_curitiba)
plt.show()

# %%
for node in G_curitiba.nodes(data=True):
    print(node)
    break
# Out:
# (250733576, {'y': -25.5608422, 'x': -49.3079335, 'street_count': 3, 'altitude_latlong_mais_proxima': '(-25.5608, -49.3083)', 'altitude_distancia_mais_proxima': '37.124', 'altitude_metros_mais_proxima': '917.0', 'dentro_poligonos': '[]', 'pontos_candidatos': '[]', 'dicionario_poligonos_mais_proximos': "{'raio_250_vizinhos_3': [{'id_poligono': 2073, 'distancia_m': 1040.37, 'dentro_poligono': False, 'poligono': 'POLYGON ((-49.3165637000000032 -25.5597542000000004, -49.3195014000000000 -25.5592576999999999, -49.3184547999999978 -25.5593550000000000, -49.3165637000000032 -25.5597542000000004))', 'cod_setor_GeoCenso_2010': 410690205070139, 'classe_social': '2 - Classe Media'}, {'id_poligono': 2007, 'distancia_m': 2450.13, 'dentro_poligono': False, 'poligono': 'POLYGON ((-49.2838862999999989 -25.5590566999999993, -49.2863514000000009 -25.5559998999999998, -49.2836495999999968 -25.5556002999999983, -49.2816560999999993 -25.5553066999999992, -49.2838862999999989 -25.5590566999999993))', 'cod_
# ...
